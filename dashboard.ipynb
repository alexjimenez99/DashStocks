# %%
import pandas as pd
import numpy  as np
import plotly 
import plotly.io as pio
import re

import dash
from dash import Dash, html, dash_table, dcc, callback, Output, Input,  State
from dash.dependencies import Input, Output

from dash.exceptions import PreventUpdate
import plotly.express as px
import pandas as pd
from zipfile import ZipFile

import yfinance as yf
from yahoo_fin import stock_info as si

import os

# Self created packages

# from database import Database

# %% [markdown]
# **End State**
# 1. Dashboard that pulls live from a website once a day using Amazon Web Servies
# 2. S3 database, Jobs that call once a day, Dashboard full workflow

# %% [markdown]
# **Load Data**

# %%
def load_data():
	'''
	'''
	with ZipFile('stock-time-series-20050101-to-20171231.zip') as zp:

		# add logic to pull stock name into data key
		data = {}

		for files in zp.namelist():
			name  = files.replace('.csv', '')

			df    = pd.read_csv(zp.open(files))
			data[name] = df

	return data

# data        = load_data()
# default_col = 'AAPL_2006-01-01_to_2018-01-01'

# %%
# Scrape the list of S&P 500 companies from Wikipedia
url         = 'https://en.wikipedia.org/wiki/List_of_S%26P_500_companies'
sp500_table = pd.read_html(url, header=0)[0]

# Extract the ticker symbols
tickers     = sp500_table['Symbol'].tolist()

# Function to get stock data for multiple companies
def get_multiple_stock_data(tickers, period='1y', interval='1d'):
    data       = {}
    news       = {}
    earnings   = {}
    financials = {}
    for ticker in tickers:
        stock        = yf.Ticker(ticker)
        stock_news   = stock.news
        
        data[ticker] = stock.history(period=period, interval=interval)
        earning      = stock.balance_sheet
        financial    = stock.financials
        data[ticker] = data[ticker].reset_index()
        data[ticker].columns = [col if col != 'Datetime' else 'Date' for col in data[ticker].columns]

        news[ticker]       = stock_news
        earnings[ticker]   = earning
        financials[ticker] = financial
        
    return data, news, earnings, financials


period_options   = ['1d', '5d', '1mo', '3mo', '6mo', '1y', '2y', '5y', '10y', 'ytd', 'max']

interval_options = ['1m', '2m', '5m', '15m', '30m', '60m', '90m', '1h', '1d', '5d', '1wk', '1mo', '3mo']

period_intervals = {'Day': ('1d', '15m'), 'Month':('1mo', '1d'), 'Year':('1y', '1d'),
                    '5 Years':('5y', '1wk'), 'Max':('max', '1mo')}

data_dictionary  = {}
for key, pair_option in period_intervals.items():
    period_option                    = pair_option[0]
    interval_option                  = pair_option[1]
    data, news, earnings, financials = get_multiple_stock_data(tickers[:20], period = period_option, interval = interval_option)
    data_dictionary[key]    = data

# %%
news['MMM']
# Out:
# [{'uuid': 'ebf0348c-6a56-36cb-b403-1df489e74ec4',
#   'title': 'Post-it Maker 3M Raises Annual Outlook After Q2 Beat, Stock Soars',
#   'publisher': 'Benzinga',
#   'link': 'https://finance.yahoo.com/news/post-maker-3m-raises-annual-140021305.html',
#   'providerPublishTime': 1722175221,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/BrJck.9IaYIVKYX9VAGgKw--~B/aD00ODA7dz03MjA7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/benzinga_79/f60b88f650086c2c3ae6ead0b73cbd5c',
#      'width': 720,
#      'height': 480,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/a0lg4QclMm2X8SmPW52p7A--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/benzinga_79/f60b88f650086c2c3ae6ead0b73cbd5c',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]},
#   'relatedTickers': ['MMM']},
#  {'uuid': 'e7916db6-4728-3460-ac24-c41be70a8c1f',
#   'title': 'Q2 2024 3M Co Earnings Call',
#   'publisher': 'Thomson Reuters StreetEvents',
#   'link': 'https://finance.yahoo.com/news/q2-2024-3m-co-earnings-085541836.html',
#   'providerPublishTime': 1722070541,
#   'type': 'STORY',
#   'relatedTickers': ['MMM']},
#  {'uuid': '9b046448-06ec-3bdd-95c6-29b3fcc1fcfe',
#   'title': '3M (MMM) Q2 2024 Earnings Call Transcript',
#   'publisher': 'Motley Fool',
#   'link': 'https://finance.yahoo.com/m/9b046448-06ec-3bdd-95c6-29b3fcc1fcfe/3m-%28mmm%29-q2-2024-earnings.html',
#   'providerPublishTime': 1722024916,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/AgPxjmk.l0_x4qaFILkqiQ--~B/aD00Mjc7dz00MDA7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/motleyfool.com/e48e86dda35543079ee2080fd9208b73',
#      'width': 400,
#      'height': 427,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/oVP_Q9NIziRyCtD.nB7xKw--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/motleyfool.com/e48e86dda35543079ee2080fd9208b73',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]},
#   'relatedTickers': ['MMM']},
#  {'uuid': '18291d4d-af87-3e0e-99b7-cc3b2ba8d08b',
#   'title': '3M Soars Most Since 1980 as New CEO Offers Glimpse of Turnaround',
#   'publisher': 'Bloomberg',
#   'link': 'https://finance.yahoo.com/news/3m-boosts-profit-forecast-ceo-105728844.html',
#   'providerPublishTime': 1722024238,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/SFyfHxaLh2iM5Bvy3QvGYw--~B/aD0xMzg3O3c9MjAwMDthcHBpZD15dGFjaHlvbg--/https://media.zenfs.com/en/bloomberg_markets_842/7bb7b43ca38b67618cdf0cc6a822bf26',
#      'width': 2000,
#      'height': 1387,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/LnOI8M2oPsD6jau1TA.zMw--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/bloomberg_markets_842/7bb7b43ca38b67618cdf0cc6a822bf26',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]},
#   'relatedTickers': ['MMM']},
#  {'uuid': '5bf5f4dd-445f-34de-b11e-20ccbf1aefd0',
#   'title': 'Midday movers: NVIDIA, Meta, Microsoft up, diabetes stock slumps',
#   'publisher': 'TheStreet',
#   'link': 'https://finance.yahoo.com/m/5bf5f4dd-445f-34de-b11e-20ccbf1aefd0/midday-movers%3A-nvidia%2C-meta%2C.html',
#   'providerPublishTime': 1722021459,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/oHeY2Y9an2pOYgxAYd.ePQ--~B/aD04MDA7dz0xMjAwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/thestreet_881/3e4166c85b823ec9720ff4cd2663b327',
#      'width': 1200,
#      'height': 800,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/y0H4jCpzu08sQskQtymLyw--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/thestreet_881/3e4166c85b823ec9720ff4cd2663b327',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]},
#   'relatedTickers': ['DECK', 'MMM', 'DXCM', '^GSPC']},
#  {'uuid': 'b7ea3519-0a05-3ca1-abc3-ad820224826b',
#   'title': "Wells Fargo Raises 3M's Price Target to $130 From $110",
#   'publisher': 'MT Newswires',
#   'link': 'https://finance.yahoo.com/news/wells-fargo-raises-3m-apos-183255098.html',
#   'providerPublishTime': 1722018775,
#   'type': 'STORY',
#   'relatedTickers': ['MMM']},
#  {'uuid': 'b60b522f-9326-308b-81da-41d3757b4698',
#   'title': 'June PCE inflation print, auto earnings: Morning Brief',
#   'publisher': 'Yahoo Finance Video',
#   'link': 'https://finance.yahoo.com/video/june-pce-inflation-print-auto-175524087.html',
#   'providerPublishTime': 1722016524,
#   'type': 'VIDEO',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/n23Of9I5fDbDwUoTFjIyfw--~B/aD0yMDYxO3c9MzY2MDthcHBpZD15dGFjaHlvbg--/https://s.yimg.com/os/creatr-uploaded-images/2024-07/364c8d40-4b78-11ef-bf7d-152c4ad9dfaa',
#      'width': 3660,
#      'height': 2061,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/Ktl_Fof.Y6u9PFg7coQsdg--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://s.yimg.com/os/creatr-uploaded-images/2024-07/364c8d40-4b78-11ef-bf7d-152c4ad9dfaa',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]},
#   'relatedTickers': ['VKTX',
#    'STLA',
#    '^IXIC',
#    'COUR',
#    'BTC-USD',
#    'DECK',
#    'GM',
#    'NSC',
#    '^DJI',
#    'LLY',
#    '^GSPC',
#    'DXCM',
#    'F',
#    'ETH-USD',
#    '300750.SZ',
#    'MMM',
#    'TSLA',
#    'NONOF',
#    'NVO']},
#  {'uuid': '227d6994-e751-3c1b-b1e3-5d7acbbab4a1',
#   'title': 'Stocks jump on cool inflation data, 3M pops on earnings: Yahoo Finance',
#   'publisher': 'Yahoo Finance Video',
#   'link': 'https://finance.yahoo.com/video/stocks-jump-cool-inflation-data-172601686.html',
#   'providerPublishTime': 1722014761,
#   'type': 'VIDEO',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/JROOHNXjo16ZbnG0EpU6Ag--~B/aD0xMDgwO3c9MTkyMDthcHBpZD15dGFjaHlvbg--/https://media-mbst-pub-ue1.s3.amazonaws.com/creatr-uploaded-images/2019-09/1af93af0-db18-11e9-bff7-e34690b9be52',
#      'width': 1920,
#      'height': 1080,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/.Pl07vIrpkJy_AGrKrtjlw--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media-mbst-pub-ue1.s3.amazonaws.com/creatr-uploaded-images/2019-09/1af93af0-db18-11e9-bff7-e34690b9be52',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]},
#   'relatedTickers': ['LULU',
#    '^GSPC',
#    '^IXIC',
#    'MMM',
#    'BMY',
#    'CELG-RT',
#    'DXCM',
#    '^DJI']}]

# %%
data_dictionary['Day']['MMM']
# Out:
#                         Date        Open        High         Low       Close  \
# 0  2024-07-19 09:30:00-04:00  104.750000  104.750000  103.489998  103.535004
# 1  2024-07-19 09:45:00-04:00  103.489998  103.869499  103.129997  103.760002
# 2  2024-07-19 10:00:00-04:00  103.760002  104.440002  103.720001  104.014999
# 3  2024-07-19 10:15:00-04:00  103.980003  104.084999  103.470100  103.510002
# 4  2024-07-19 10:30:00-04:00  103.500000  104.379997  103.459999  104.330002
# 5  2024-07-19 10:45:00-04:00  104.320000  104.467499  103.695000  103.930000
# 6  2024-07-19 11:00:00-04:00  103.930000  104.105003  103.709999  103.714996
# 7  2024-07-19 11:15:00-04:00  103.750000  104.214996  103.730003  103.754997
# 8  2024-07-19 11:30:00-04:00  103.760002  103.980003  103.676903  103.800003
# 9  2024-07-19 11:45:00-04:00  103.800003  104.250000  103.760002  104.230003
# 10 2024-07-19 12:00:00-04:00  104.230003  104.500000  104.175003  104.500000
# 11 2024-07-19 12:15:00-04:00  104.529999  104.660004  104.370003  104.400002
# 12 2024-07-19 12:30:00-04:00  104.410004  104.489998  104.324997  104.430000
# 13 2024-07-19 12:45:00-04:00  104.449997  104.480003  104.269897  104.290001
# 14 2024-07-19 13:00:00-04:00  104.309998  104.459999  104.239998  104.400002
# 15 2024-07-19 13:15:00-04:00  104.415001  104.415001  104.035004  104.099998
# 16 2024-07-19 13:30:00-04:00  104.089996  104.089996  103.809998  103.898201
# 17 2024-07-19 13:45:00-04:00  103.919998  104.300003  103.910004  104.260002
# 18 2024-07-19 14:00:00-04:00  104.239998  104.239998  103.919998  104.029999
# 19 2024-07-19 14:15:00-04:00  104.050003  104.209999  103.995003  104.000000
# 20 2024-07-19 14:30:00-04:00  104.004997  104.099998  103.955002  103.989998
# 21 2024-07-19 14:45:00-04:00  103.980003  104.099998  103.889999  103.919998
# 22 2024-07-19 15:00:00-04:00  103.934998  104.320000  103.934998  104.269997
# 23 2024-07-19 15:15:00-04:00  104.260002  104.379997  104.139999  104.169998
# 24 2024-07-19 15:30:00-04:00  104.180000  104.199997  104.029999  104.080002
# 25 2024-07-19 15:45:00-04:00  104.099998  104.150002  103.790001  103.919998
#
#     Volume  Dividends  Stock Splits
# 0   286460        0.0           0.0
# 1    64481        0.0           0.0
# 2    92685        0.0           0.0
# 3    57169        0.0           0.0
# 4   103153        0.0           0.0
# 5    76515        0.0           0.0
# 6    91709        0.0           0.0
# 7    68856        0.0           0.0
# 8    61019        0.0           0.0
# 9    59713        0.0           0.0
# 10   54722        0.0           0.0
# 11   55717        0.0           0.0
# 12   71677        0.0           0.0
# 13   48520        0.0           0.0
# 14   48653        0.0           0.0
# 15   82546        0.0           0.0
# 16   46066        0.0           0.0
# 17   39201        0.0           0.0
# 18   48060        0.0           0.0
# 19   44918        0.0           0.0
# 20   40823        0.0           0.0
# 21   52570        0.0           0.0
# 22   72124        0.0           0.0
# 23   71138        0.0           0.0
# 24  111317        0.0           0.0
# 25  492894        0.0           0.0

# %%
counter = 0 
for key in news.keys():
	news[key] = pd.DataFrame(news[key])
	news[key] = news[key].drop(columns = ['thumbnail', 'uuid'])
	if counter > 2:
		break
	
	counter += 1

# %%
news['MMM']
# Out:
#                                                title        publisher  \
# 0                         Is 3M a Millionaire Maker?      Motley Fool
# 1  3M (MMM) Expected to Beat Earnings Estimates: ...            Zacks
# 2  GE Aerospace (GE) to Report Q2 Earnings: What ...            Zacks
# 3  3M (MMM) Rises 13.4% in 3 Months: How Should Y...            Zacks
# 4  3M (MMM) Ascends While Market Falls: Some Fact...            Zacks
# 5  3M invests in green hydrogen leader Ohmium in ...      PR Newswire
# 6  Three US Stocks Estimated To Be Trading Below ...  Simply Wall St.
# 7  The 3 Most Undervalued Dow Stocks to Buy in Ju...    InvestorPlace
#
#                                                 link  providerPublishTime  \
# 0  https://finance.yahoo.com/m/dd617720-d961-3c66...           1721462580
# 1  https://finance.yahoo.com/news/3m-mmm-expected...           1721397619
# 2  https://finance.yahoo.com/news/ge-aerospace-ge...           1721396940
# 3  https://finance.yahoo.com/news/3m-mmm-rises-13...           1721312700
# 4  https://finance.yahoo.com/news/3m-mmm-ascends-...           1721252720
# 5  https://finance.yahoo.com/news/3m-invests-gree...           1721142000
# 6  https://finance.yahoo.com/news/three-us-stocks...           1720782216
# 7  https://finance.yahoo.com/news/3-most-underval...           1720717200
#
#     type          relatedTickers
# 0  STORY                   [MMM]
# 1  STORY              [HON, MMM]
# 2  STORY                   [MMM]
# 3  STORY                   [MMM]
# 4  STORY                   [MMM]
# 5  STORY                   [MMM]
# 6  STORY  [MMM, LAAOF, LI, BMRN]
# 7  STORY             [^DJI, MMM]

# %%
financials['MMM'].transpose().reset_index()
# Out:
#        index Tax Effect Of Unusual Items Tax Rate For Calcs Normalized EBITDA  \
# 0 2023-12-31                  10008000.0              0.278     -6795000000.0
# 1 2022-12-31                 235488000.0              0.096      6232000000.0
# 2 2021-12-31                         0.0              0.178      9607000000.0
# 3 2020-12-31                  76633000.0              0.197      8846000000.0
# 4 2019-12-31                         NaN                NaN               NaN
#
#   Total Unusual Items Total Unusual Items Excluding Goodwill  \
# 0          36000000.0                             36000000.0
# 1        2453000000.0                           2453000000.0
# 2                 0.0                                    0.0
# 3         389000000.0                            389000000.0
# 4                 NaN                                    NaN
#
#   Net Income From Continuing Operation Net Minority Interest  \
# 0                                      -6995000000.0
# 1                                       5777000000.0
# 2                                       5921000000.0
# 3                                       5449000000.0
# 4                                                NaN
#
#   Reconciled Depreciation Reconciled Cost Of Revenue        EBITDA  ...  \
# 0            1987000000.0              18477000000.0 -6759000000.0  ...
# 1            1831000000.0              19232000000.0  8685000000.0  ...
# 2            1915000000.0              18795000000.0  9607000000.0  ...
# 3            1911000000.0              16605000000.0  9235000000.0  ...
# 4                     NaN                        NaN           NaN  ...
#
#   Operating Expense Research And Development  \
# 0     23239000000.0             1842000000.0
# 1     10663000000.0             1862000000.0
# 2      8894000000.0             1994000000.0
# 3      8673000000.0             1878000000.0
# 4               NaN                      NaN
#
#   Selling General And Administration General And Administrative Expense  \
# 0                      21397000000.0                      21397000000.0
# 1                       8801000000.0                       8801000000.0
# 2                       6900000000.0                       6900000000.0
# 3                       6795000000.0                       6795000000.0
# 4                                NaN                                NaN
#
#     Other Gand A Salaries And Wages   Gross Profit Cost Of Revenue  \
# 0  21526000000.0       -129000000.0  14204000000.0   18477000000.0
# 1   9049000000.0       -248000000.0  14997000000.0   19232000000.0
# 2   7197000000.0       -297000000.0  16560000000.0   18795000000.0
# 3   6929000000.0       -134000000.0  15579000000.0   16605000000.0
# 4            NaN                NaN            NaN             NaN
#
#    Total Revenue Operating Revenue
# 0  32681000000.0     32681000000.0
# 1  34229000000.0     34229000000.0
# 2  35355000000.0     35355000000.0
# 3  32184000000.0     32184000000.0
# 4            NaN               NaN
#
# [5 rows x 50 columns]

# %%
earnings['MMM'].transpose().reset_index().columns
# Out:
# Index(['index', 'Treasury Shares Number', 'Ordinary Shares Number',
#        'Share Issued', 'Net Debt', 'Total Debt', 'Tangible Book Value',
#        'Invested Capital', 'Working Capital', 'Net Tangible Assets',
#        'Capital Lease Obligations', 'Common Stock Equity',
#        'Total Capitalization', 'Total Equity Gross Minority Interest',
#        'Minority Interest', 'Stockholders Equity',
#        'Gains Losses Not Affecting Retained Earnings',
#        'Other Equity Adjustments', 'Treasury Stock', 'Retained Earnings',
#        'Additional Paid In Capital', 'Capital Stock', 'Common Stock',
#        'Total Liabilities Net Minority Interest',
#        'Total Non Current Liabilities Net Minority Interest',
#        'Other Non Current Liabilities', 'Employee Benefits',
#        'Non Current Pension And Other Postretirement Benefit Plans',
#        'Tradeand Other Payables Non Current',
#        'Non Current Deferred Liabilities',
#        'Non Current Deferred Taxes Liabilities',
#        'Long Term Debt And Capital Lease Obligation',
#        'Long Term Capital Lease Obligation', 'Long Term Debt',
#        'Current Liabilities', 'Other Current Liabilities',
#        'Current Deferred Liabilities', 'Current Deferred Revenue',
#        'Current Debt And Capital Lease Obligation',
#        'Current Capital Lease Obligation', 'Current Debt',
#        'Other Current Borrowings', 'Line Of Credit', 'Commercial Paper',
#        'Pensionand Other Post Retirement Benefit Plans Current',
#        'Payables And Accrued Expenses', 'Current Accrued Expenses', 'Payables',
#        'Total Tax Payable', 'Income Tax Payable', 'Accounts Payable',
#        'Total Assets', 'Total Non Current Assets', 'Other Non Current Assets',
#        'Defined Pension Benefit', 'Non Current Deferred Assets',
#        'Non Current Deferred Taxes Assets', 'Non Current Accounts Receivable',
#        'Investments And Advances', 'Investmentin Financial Assets',
#        'Long Term Equity Investment', 'Goodwill And Other Intangible Assets',
#        'Other Intangible Assets', 'Goodwill', 'Net PPE',
#        'Accumulated Depreciation', 'Gross PPE', 'Construction In Progress',
#        'Other Properties', 'Machinery Furniture Equipment',
#        'Buildings And Improvements', 'Land And Improvements', 'Properties',
#        'Current Assets', 'Other Current Assets', 'Hedging Assets Current',
#        'Restricted Cash', 'Prepaid Assets', 'Inventory', 'Finished Goods',
#        'Work In Process', 'Raw Materials', 'Receivables', 'Other Receivables',
#        'Accounts Receivable', 'Allowance For Doubtful Accounts Receivable',
#        'Gross Accounts Receivable',
#        'Cash Cash Equivalents And Short Term Investments',
#        'Other Short Term Investments', 'Cash And Cash Equivalents'],
#       dtype='object')

# %%
type(earnings['MMM'].transpose()[col].iloc[0])
# Out:
# float

# %%
for col in earnings['MMM'].transpose().columns:
	print(type(earnings['MMM'].transpose()[col].iloc[0]))
# Out:
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>

# %%
dummy = earnings['MMM'].transpose().reset_index()
dummy.columns = [col if col!= 'index' else 'Date' for col in dummy.columns ]
dummy
# Out:
#         Date Treasury Shares Number Ordinary Shares Number Share Issued  \
# 0 2023-12-31            391451920.0            552581136.0  944033056.0
# 1 2022-12-31            394787951.0            549245105.0  944033056.0
# 2 2021-12-31            372187578.0            571845478.0  944033056.0
# 3 2020-12-31            366283418.0            577749638.0  944033056.0
# 4 2019-12-31                    NaN                    NaN          NaN
#
#         Net Debt     Total Debt Tangible Book Value Invested Capital  \
# 0  10102000000.0  16854000000.0      -12346000000.0    20842000000.0
# 1  12284000000.0  16855000000.0       -2767000000.0    30661000000.0
# 2  12799000000.0  18310000000.0       -3728000000.0    32409000000.0
# 3  14161000000.0  19753000000.0       -6770000000.0    31662000000.0
# 4            NaN            NaN                 NaN              NaN
#
#   Working Capital Net Tangible Assets  ... Work In Process Raw Materials  \
# 0    1082000000.0      -12346000000.0  ...    1424000000.0  1105000000.0
# 1    5165000000.0       -2767000000.0  ...    1606000000.0  1269000000.0
# 2    6368000000.0       -3728000000.0  ...    1577000000.0  1212000000.0
# 3    7034000000.0       -6770000000.0  ...    1226000000.0   932000000.0
# 4             NaN                 NaN  ...             NaN           NaN
#
#     Receivables Other Receivables Accounts Receivable  \
# 0  4864000000.0       114000000.0        4750000000.0
# 1  4635000000.0       103000000.0        4532000000.0
# 2  4770000000.0       110000000.0        4660000000.0
# 3  4830000000.0       125000000.0        4705000000.0
# 4           NaN               NaN                 NaN
#
#   Allowance For Doubtful Accounts Receivable Gross Accounts Receivable  \
# 0                               -141000000.0              4891000000.0
# 1                               -174000000.0              4706000000.0
# 2                               -189000000.0              4849000000.0
# 3                               -233000000.0              4938000000.0
# 4                                        NaN                       NaN
#
#   Cash Cash Equivalents And Short Term Investments  \
# 0                                     5986000000.0
# 1                                     3893000000.0
# 2                                     4765000000.0
# 3                                     5038000000.0
# 4                                              NaN
#
#   Other Short Term Investments Cash And Cash Equivalents
# 0                   53000000.0              5933000000.0
# 1                  238000000.0              3655000000.0
# 2                  201000000.0              4564000000.0
# 3                  404000000.0              4634000000.0
# 4                          NaN                       NaN
#
# [5 rows x 90 columns]

# %%
news[key]
# Out:
#                                                title  \
# 0            What To Expect in the Markets This Week
# 1  AbbVie (ABBV) Rises As Market Takes a Dip: Key...
# 2  Tesla, Alphabet, Visa earnings, June PCE data:...
# 3  Boehringer Ingelheim offers Humira biosimilar ...
# 4  Pharma Stock Roundup: JNJ, NVS Q2 Earnings, RH...
# 5  Investors in AbbVie (NYSE:ABBV) have seen stro...
# 6  Earnings Preview: AbbVie (ABBV) Q2 Earnings Ex...
# 7  Boehringer cuts price of Humira biosimilar in ...
#
#                    publisher  \
# 0               Investopedia
# 1                      Zacks
# 2        Yahoo Finance Video
# 3  Pharmaceutical Technology
# 4                      Zacks
# 5            Simply Wall St.
# 6                      Zacks
# 7             BioPharma Dive
#
#                                                 link  providerPublishTime  \
# 0  https://finance.yahoo.com/m/86aee722-448d-36b8...           1721559600
# 1  https://finance.yahoo.com/news/abbvie-abbv-ris...           1721425519
# 2  https://finance.yahoo.com/video/tesla-alphabet...           1721424828
# 3  https://finance.yahoo.com/m/d149db51-5b24-3754...           1721402019
# 4  https://finance.yahoo.com/news/pharma-stock-ro...           1721395560
# 5  https://finance.yahoo.com/news/investors-abbvi...           1721394026
# 6  https://finance.yahoo.com/news/earnings-previe...           1721311283
# 7  https://finance.yahoo.com/m/f76fdc97-ca9e-398a...           1721302980
#
#     type                                     relatedTickers
# 0  STORY                                 [TSLA, GOOG, ABBV]
# 1  STORY                                             [ABBV]
# 2  VIDEO  [KO, VZ, STLA, ABBV, V, CMCSA, GOOG, TSLA, IBM...
# 3  STORY                                  [ABBV, GDRX, CVS]
# 4  STORY                                [NVS, ABBV, ROG.SW]
# 5  STORY                                             [ABBV]
# 6  STORY                                             [ABBV]
# 7  STORY                                             [ABBV]

# %%
news['MMM']
# Out:
# [{'uuid': 'dd617720-d961-3c66-b0be-9988d65f6ca4',
#   'title': 'Is 3M a Millionaire Maker?',
#   'publisher': 'Motley Fool',
#   'link': 'https://finance.yahoo.com/m/dd617720-d961-3c66-b0be-9988d65f6ca4/is-3m-a-millionaire-maker%3F.html',
#   'providerPublishTime': 1721462580,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/sXf3kLS2RkF5Pm9JPCCrgA--~B/aD05MzM7dz0xNDAwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/motleyfool.com/dae4dd40c7c52f64e3cb535da15506e9',
#      'width': 1400,
#      'height': 933,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/RNC_yUsR.ehogid43Lsp.Q--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/motleyfool.com/dae4dd40c7c52f64e3cb535da15506e9',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]},
#   'relatedTickers': ['MMM']},
#  {'uuid': 'fedaf7f3-17c4-3a59-90a3-c6715b714af2',
#   'title': '3M (MMM) Expected to Beat Earnings Estimates: What to Know Ahead of Q2 Release',
#   'publisher': 'Zacks',
#   'link': 'https://finance.yahoo.com/news/3m-mmm-expected-beat-earnings-140019860.html',
#   'providerPublishTime': 1721397619,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/XFzKRSTb2_xUaLSOCP9.Bg--~B/aD02MDI7dz05MDA7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/zacks.com/a41b81fe729c761f3f94f42ff348f70c',
#      'width': 900,
#      'height': 602,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/UF5vS9CCA_LIuCo4lg9rzA--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/zacks.com/a41b81fe729c761f3f94f42ff348f70c',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]},
#   'relatedTickers': ['HON', 'MMM']},
#  {'uuid': '1cbbd8ef-8b5a-3536-84cd-f33d3d1c3536',
#   'title': 'GE Aerospace (GE) to Report Q2 Earnings: What to Expect?',
#   'publisher': 'Zacks',
#   'link': 'https://finance.yahoo.com/news/ge-aerospace-ge-report-q2-134900475.html',
#   'providerPublishTime': 1721396940,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/r398vJtFFDOHb5rdOUCmGQ--~B/aD00MDA7dz02MzU7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/zacks.com/ff346dd52d285665b4a52c89d00c4e50',
#      'width': 635,
#      'height': 400,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/LbEK9sFKIbMl.J24YPxqsg--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/zacks.com/ff346dd52d285665b4a52c89d00c4e50',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]},
#   'relatedTickers': ['MMM']},
#  {'uuid': 'da7f9da5-ece8-399f-a6c0-ee7df4d419e4',
#   'title': '3M (MMM) Rises 13.4% in 3 Months: How Should You Play the Stock?',
#   'publisher': 'Zacks',
#   'link': 'https://finance.yahoo.com/news/3m-mmm-rises-13-4-142500904.html',
#   'providerPublishTime': 1721312700,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/LuqJ.M0lv3PgCi9zLWh7.g--~B/aD00MDA7dz02MzU7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/zacks.com/16ec952cfd7d1ba98a87b6957f1f19a2',
#      'width': 635,
#      'height': 400,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/PRlFX6UdIyphObF1x7zVEg--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/zacks.com/16ec952cfd7d1ba98a87b6957f1f19a2',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]},
#   'relatedTickers': ['MMM']},
#  {'uuid': '3b59544e-93ce-3acb-a52e-6953a0b65cd2',
#   'title': '3M (MMM) Ascends While Market Falls: Some Facts to Note',
#   'publisher': 'Zacks',
#   'link': 'https://finance.yahoo.com/news/3m-mmm-ascends-while-market-214520772.html',
#   'providerPublishTime': 1721252720,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/gUf3JPAiwp3PVjuDKftvaA--~B/aD04NDU7dz05MDA7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/zacks.com/26a86d59f0e8f1e82a35a92ae5684cd9',
#      'width': 900,
#      'height': 845,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/HpYEBsELOHKKt9_5_oEt0Q--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/zacks.com/26a86d59f0e8f1e82a35a92ae5684cd9',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]},
#   'relatedTickers': ['MMM']},
#  {'uuid': 'ac7cb93f-45bc-35ff-8618-94e1d8ce2b66',
#   'title': '3M invests in green hydrogen leader Ohmium in continuing effort to advance breakthrough climate technologies',
#   'publisher': 'PR Newswire',
#   'link': 'https://finance.yahoo.com/news/3m-invests-green-hydrogen-leader-150000911.html',
#   'providerPublishTime': 1721142000,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/G_Jv1a5D584Pwelv9fZq.w--~B/aD0yNTA7dz00MDA7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/prnewswire.com/501c67750c8fe6aa93765bf707476fcf',
#      'width': 400,
#      'height': 250,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/md7YnmELdezxCUKWeKj7EQ--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/prnewswire.com/501c67750c8fe6aa93765bf707476fcf',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]},
#   'relatedTickers': ['MMM']},
#  {'uuid': 'd4aa7de8-9b6a-35c2-9663-3e286baf2262',
#   'title': 'Three US Stocks Estimated To Be Trading Below Their Intrinsic Values In July 2024',
#   'publisher': 'Simply Wall St.',
#   'link': 'https://finance.yahoo.com/news/three-us-stocks-estimated-trading-110336745.html',
#   'providerPublishTime': 1720782216,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/quebi07.EX4jRg4LNdHS1w--~B/aD00MzI7dz0xMTk0O2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/simply_wall_st__316/2df876d5c79edcee5d914115d85637db',
#      'width': 1194,
#      'height': 432,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/nZTHlX7cOzlHlwkc0oPVoA--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/simply_wall_st__316/2df876d5c79edcee5d914115d85637db',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]},
#   'relatedTickers': ['MMM', 'LAAOF', 'LI', 'BMRN']},
#  {'uuid': '59e4c6a2-22e9-3329-944f-ac984cc9c5b0',
#   'title': 'The 3 Most Undervalued Dow Stocks to Buy in July 2024',
#   'publisher': 'InvestorPlace',
#   'link': 'https://finance.yahoo.com/news/3-most-undervalued-dow-stocks-170000743.html',
#   'providerPublishTime': 1720717200,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/LMtS32CwV2rkZT1ZebiiLw--~B/aD00MDA7dz03Mjg7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/investorplace_417/b1777039a2866295c1bd36e1747ff216',
#      'width': 728,
#      'height': 400,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/ZGRjBulq7quMg6uXZwf75g--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/investorplace_417/b1777039a2866295c1bd36e1747ff216',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]},
#   'relatedTickers': ['^DJI', 'MMM']}]

# %%
data_dictionary['Day']['MMM']
# Out:
#                         Date        Open        High         Low       Close  \
# 0  2024-07-19 09:30:00-04:00  104.750000  104.750000  103.489998  103.535004
# 1  2024-07-19 09:45:00-04:00  103.489998  103.869499  103.129997  103.760002
# 2  2024-07-19 10:00:00-04:00  103.760002  104.440002  103.720001  104.014999
# 3  2024-07-19 10:15:00-04:00  103.980003  104.084999  103.470100  103.510002
# 4  2024-07-19 10:30:00-04:00  103.500000  104.379997  103.459999  104.330002
# 5  2024-07-19 10:45:00-04:00  104.320000  104.467499  103.695000  103.930000
# 6  2024-07-19 11:00:00-04:00  103.930000  104.105003  103.709999  103.714996
# 7  2024-07-19 11:15:00-04:00  103.750000  104.214996  103.730003  103.754997
# 8  2024-07-19 11:30:00-04:00  103.760002  103.980003  103.676903  103.800003
# 9  2024-07-19 11:45:00-04:00  103.800003  104.250000  103.760002  104.230003
# 10 2024-07-19 12:00:00-04:00  104.230003  104.500000  104.175003  104.500000
# 11 2024-07-19 12:15:00-04:00  104.529999  104.660004  104.370003  104.400002
# 12 2024-07-19 12:30:00-04:00  104.410004  104.489998  104.324997  104.430000
# 13 2024-07-19 12:45:00-04:00  104.449997  104.480003  104.269897  104.290001
# 14 2024-07-19 13:00:00-04:00  104.309998  104.459999  104.239998  104.400002
# 15 2024-07-19 13:15:00-04:00  104.415001  104.415001  104.035004  104.099998
# 16 2024-07-19 13:30:00-04:00  104.089996  104.089996  103.809998  103.898201
# 17 2024-07-19 13:45:00-04:00  103.919998  104.300003  103.910004  104.260002
# 18 2024-07-19 14:00:00-04:00  104.239998  104.239998  103.919998  104.029999
# 19 2024-07-19 14:15:00-04:00  104.050003  104.209999  103.995003  104.000000
# 20 2024-07-19 14:30:00-04:00  104.004997  104.099998  103.955002  103.989998
# 21 2024-07-19 14:45:00-04:00  103.980003  104.099998  103.889999  103.919998
# 22 2024-07-19 15:00:00-04:00  103.934998  104.320000  103.934998  104.269997
# 23 2024-07-19 15:15:00-04:00  104.260002  104.379997  104.139999  104.169998
# 24 2024-07-19 15:30:00-04:00  104.180000  104.199997  104.029999  104.080002
# 25 2024-07-19 15:45:00-04:00  104.099998  104.150002  103.790001  103.919998
#
#     Volume  Dividends  Stock Splits
# 0   286460        0.0           0.0
# 1    64481        0.0           0.0
# 2    92685        0.0           0.0
# 3    57169        0.0           0.0
# 4   103153        0.0           0.0
# 5    76515        0.0           0.0
# 6    91709        0.0           0.0
# 7    68856        0.0           0.0
# 8    61019        0.0           0.0
# 9    59713        0.0           0.0
# 10   54722        0.0           0.0
# 11   55717        0.0           0.0
# 12   71677        0.0           0.0
# 13   48520        0.0           0.0
# 14   48653        0.0           0.0
# 15   82546        0.0           0.0
# 16   46066        0.0           0.0
# 17   39201        0.0           0.0
# 18   48060        0.0           0.0
# 19   44918        0.0           0.0
# 20   40823        0.0           0.0
# 21   52570        0.0           0.0
# 22   72124        0.0           0.0
# 23   71138        0.0           0.0
# 24  111317        0.0           0.0
# 25  492894        0.0           0.0

# %%
# db = Database()
# db.insert_stock_prices(data_dictionary['Max'])
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sqlalchemy/engine/base.py:1933, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1932     if not evt_handled:
# -> 1933         self.dialect.do_executemany(
#    1934             cursor,
#    1935             str_statement,
#    1936             effective_parameters,
#    1937             context,
#    1938         )
#    1939 elif not effective_parameters and context.no_parameters:
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sqlalchemy/engine/default.py:745, in DefaultDialect.do_executemany(self, cursor, statement, parameters, context)
#     744 def do_executemany(self, cursor, statement, parameters, context=None):
# --> 745     cursor.executemany(statement, parameters)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/mysql/connector/cursor.py:671, in MySQLCursor.executemany(self, operation, seq_params)
#     670 for params in seq_params:
# --> 671     self.execute(operation, params)
#     672     if self.with_rows and self._have_unread_result():
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/mysql/connector/cursor.py:564, in MySQLCursor.execute(self, operation, params, multi)
#     563 try:
# --> 564     self._handle_result(self._connection.cmd_query(stmt))
#     565 except InterfaceError as err:
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/mysql/connector/connection.py:990, in MySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string)
#     989 try:
# --> 990     result = self._handle_result(self._send_cmd(ServerCmd.QUERY, query))
#     991 except ProgrammingError as err:
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/mysql/connector/connection.py:784, in MySQLConnection._handle_result(self, packet)
#     783 if packet[4] == 255:
# --> 784     raise get_exception(packet)
#     786 # We have a text result set
#
# ProgrammingError: 1054 (42S22): Unknown column 'Date' in 'field list'
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# Input In [4], in <cell line: 2>()
#       1 db = Database()
# ----> 2 db.insert_stock_prices(data_dictionary['Max'])
#
# File ~/Desktop/Current Desktop/Desktop/Code/Resume Code (GoogleDrive)/plotly_dashboard/stock_dashboard/database.py:125, in Database.insert_stock_prices(self, data)
#     123 	for key in data.keys():
#     124 		company_data = data[key]
# --> 125 		company_data.to_sql('lifetime_stocks', con=engine, if_exists='append', index=False)
#     127 return
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/generic.py:2987, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2830 """
#    2831 Write records stored in a DataFrame to a SQL database.
#    2832
#    (...)
#    2983 [(1,), (None,), (2,)]
#    2984 """  # noqa:E501
#    2985 from pandas.io import sql
# -> 2987 return sql.to_sql(
#    2988     self,
#    2989     name,
#    2990     con,
#    2991     schema=schema,
#    2992     if_exists=if_exists,
#    2993     index=index,
#    2994     index_label=index_label,
#    2995     chunksize=chunksize,
#    2996     dtype=dtype,
#    2997     method=method,
#    2998 )
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/io/sql.py:695, in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     690 elif not isinstance(frame, DataFrame):
#     691     raise NotImplementedError(
#     692         "'frame' argument should be either a Series or a DataFrame"
#     693     )
# --> 695 return pandas_sql.to_sql(
#     696     frame,
#     697     name,
#     698     if_exists=if_exists,
#     699     index=index,
#     700     index_label=index_label,
#     701     schema=schema,
#     702     chunksize=chunksize,
#     703     dtype=dtype,
#     704     method=method,
#     705     engine=engine,
#     706     **engine_kwargs,
#     707 )
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/io/sql.py:1738, in SQLDatabase.to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    1726 sql_engine = get_engine(engine)
#    1728 table = self.prep_table(
#    1729     frame=frame,
#    1730     name=name,
#    (...)
#    1735     dtype=dtype,
#    1736 )
# -> 1738 total_inserted = sql_engine.insert_records(
#    1739     table=table,
#    1740     con=self.connectable,
#    1741     frame=frame,
#    1742     name=name,
#    1743     index=index,
#    1744     schema=schema,
#    1745     chunksize=chunksize,
#    1746     method=method,
#    1747     **engine_kwargs,
#    1748 )
#    1750 self.check_case_sensitive(name=name, schema=schema)
#    1751 return total_inserted
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/io/sql.py:1335, in SQLAlchemyEngine.insert_records(self, table, con, frame, name, index, schema, chunksize, method, **engine_kwargs)
#    1333     raise ValueError("inf cannot be used with MySQL") from err
#    1334 else:
# -> 1335     raise err
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/io/sql.py:1325, in SQLAlchemyEngine.insert_records(self, table, con, frame, name, index, schema, chunksize, method, **engine_kwargs)
#    1322 from sqlalchemy import exc
#    1324 try:
# -> 1325     return table.insert(chunksize=chunksize, method=method)
#    1326 except exc.SQLAlchemyError as err:
#    1327     # GH34431
#    1328     # https://stackoverflow.com/a/67358288/6067848
#    1329     msg = r"""(\(1054, "Unknown column 'inf(e0)?' in 'field list'"\))(?#
#    1330     )|inf can not be used with MySQL"""
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/io/sql.py:946, in SQLTable.insert(self, chunksize, method)
#     943     break
#     945 chunk_iter = zip(*(arr[start_i:end_i] for arr in data_list))
# --> 946 num_inserted = exec_insert(conn, keys, chunk_iter)
#     947 # GH 46891
#     948 if is_integer(num_inserted):
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/io/sql.py:853, in SQLTable._execute_insert(self, conn, keys, data_iter)
#     841 """
#     842 Execute SQL statement inserting data
#     843
#    (...)
#     850    Each item contains a list of values to be inserted
#     851 """
#     852 data = [dict(zip(keys, row)) for row in data_iter]
# --> 853 result = conn.execute(self.table.insert(), data)
#     854 return result.rowcount
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sqlalchemy/engine/base.py:1414, in Connection.execute(self, statement, parameters, execution_options)
#    1412     raise exc.ObjectNotExecutableError(statement) from err
#    1413 else:
# -> 1414     return meth(
#    1415         self,
#    1416         distilled_parameters,
#    1417         execution_options or NO_OPTIONS,
#    1418     )
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sqlalchemy/sql/elements.py:486, in ClauseElement._execute_on_connection(self, connection, distilled_params, execution_options)
#     484     if TYPE_CHECKING:
#     485         assert isinstance(self, Executable)
# --> 486     return connection._execute_clauseelement(
#     487         self, distilled_params, execution_options
#     488     )
#     489 else:
#     490     raise exc.ObjectNotExecutableError(self)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sqlalchemy/engine/base.py:1638, in Connection._execute_clauseelement(self, elem, distilled_parameters, execution_options)
#    1626 compiled_cache: Optional[CompiledCacheType] = execution_options.get(
#    1627     "compiled_cache", self.engine._compiled_cache
#    1628 )
#    1630 compiled_sql, extracted_params, cache_hit = elem._compile_w_cache(
#    1631     dialect=dialect,
#    1632     compiled_cache=compiled_cache,
#    (...)
#    1636     linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1637 )
# -> 1638 ret = self._execute_context(
#    1639     dialect,
#    1640     dialect.execution_ctx_cls._init_compiled,
#    1641     compiled_sql,
#    1642     distilled_parameters,
#    1643     execution_options,
#    1644     compiled_sql,
#    1645     distilled_parameters,
#    1646     elem,
#    1647     extracted_params,
#    1648     cache_hit=cache_hit,
#    1649 )
#    1650 if has_events:
#    1651     self.dispatch.after_execute(
#    1652         self,
#    1653         elem,
#    (...)
#    1657         ret,
#    1658     )
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sqlalchemy/engine/base.py:1842, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1837     return self._exec_insertmany_context(
#    1838         dialect,
#    1839         context,
#    1840     )
#    1841 else:
# -> 1842     return self._exec_single_context(
#    1843         dialect, context, statement, parameters
#    1844     )
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sqlalchemy/engine/base.py:1983, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1980     result = context._setup_result_proxy()
#    1982 except BaseException as e:
# -> 1983     self._handle_dbapi_exception(
#    1984         e, str_statement, effective_parameters, cursor, context
#    1985     )
#    1987 return result
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sqlalchemy/engine/base.py:2326, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context, is_sub_exec)
#    2324 elif should_wrap:
#    2325     assert sqlalchemy_exception is not None
# -> 2326     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2327 else:
#    2328     assert exc_info[1] is not None
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sqlalchemy/engine/base.py:1933, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1931                 break
#    1932     if not evt_handled:
# -> 1933         self.dialect.do_executemany(
#    1934             cursor,
#    1935             str_statement,
#    1936             effective_parameters,
#    1937             context,
#    1938         )
#    1939 elif not effective_parameters and context.no_parameters:
#    1940     if self.dialect._has_events:
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sqlalchemy/engine/default.py:745, in DefaultDialect.do_executemany(self, cursor, statement, parameters, context)
#     744 def do_executemany(self, cursor, statement, parameters, context=None):
# --> 745     cursor.executemany(statement, parameters)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/mysql/connector/cursor.py:671, in MySQLCursor.executemany(self, operation, seq_params)
#     669 try:
#     670     for params in seq_params:
# --> 671         self.execute(operation, params)
#     672         if self.with_rows and self._have_unread_result():
#     673             self.fetchall()
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/mysql/connector/cursor.py:564, in MySQLCursor.execute(self, operation, params, multi)
#     561     return self._execute_iter(self._connection.cmd_query_iter(stmt))
#     563 try:
# --> 564     self._handle_result(self._connection.cmd_query(stmt))
#     565 except InterfaceError as err:
#     566     if self._connection.have_next_result:
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/mysql/connector/connection.py:990, in MySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string)
#     988 query = bytes(packet)
#     989 try:
# --> 990     result = self._handle_result(self._send_cmd(ServerCmd.QUERY, query))
#     991 except ProgrammingError as err:
#     992     if err.errno == 3948 and "Loading local data is disabled" in err.msg:
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/mysql/connector/connection.py:784, in MySQLConnection._handle_result(self, packet)
#     782     return self._handle_eof(packet)
#     783 if packet[4] == 255:
# --> 784     raise get_exception(packet)
#     786 # We have a text result set
#     787 column_count = self._protocol.parse_column_count(packet)
#
# ProgrammingError: (mysql.connector.errors.ProgrammingError) 1054 (42S22): Unknown column 'Date' in 'field list'
# [SQL: INSERT INTO lifetime_stocks (`Date`, `Open`, `High`, `Low`, `Close`, `Volume`, `Dividends`, `Stock Splits`) VALUES (%(Date)s, %(Open)s, %(High)s, %(Low)s, %(Close)s, %(Volume)s, %(Dividends)s, %(Stock_Splits)s)]
# [parameters: [{'Date': datetime.datetime(1962, 2, 1, 0, 0, tzinfo=<DstTzInfo 'America/New_York' EST-1 day, 19:00:00 STD>), 'Open': 0.0, 'High': 0.42587024857359296, 'Low': 0.3948013868809007, 'Close': 0.40465253591537476, 'Volume': 3408123, 'Dividends': 0.0125, 'Stock_Splits': 0.0}, {'Date': datetime.datetime(1962, 3, 1, 0, 0, tzinfo=<DstTzInfo 'America/New_York' EST-1 day, 19:00:00 STD>), 'Open': 0.0, 'High': 0.4266525172912799, 'Low': 0.3954711309074974, 'Close': 0.42513152956962585, 'Volume': 4081711, 'Dividends': 0.0, 'Stock_Splits': 0.0}, {'Date': datetime.datetime(1962, 4, 1, 0, 0, tzinfo=<DstTzInfo 'America/New_York' EST-1 day, 19:00:00 STD>), 'Open': 0.0, 'High': 0.42589229775347004, 'Low': 0.38634514808654785, 'Close': 0.38634514808654785, 'Volume': 3496148, 'Dividends': 0.0, 'Stock_Splits': 0.0}, {'Date': datetime.datetime(1962, 5, 1, 0, 0, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>), 'Open': 0.0, 'High': 0.4190475863576888, 'Low': 0.3057298712455953, 'Close': 0.33462968468666077, 'Volume': 7757734, 'Dividends': 0.0, 'Stock_Splits': 0.0}, {'Date': datetime.datetime(1962, 6, 1, 0, 0, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>), 'Open': 0.0, 'High': 0.3429953120945184, 'Low': 0.25021169081495803, 'Close': 0.28519558906555176, 'Volume': 13492793, 'Dividends': 0.0, 'Stock_Splits': 0.0}, {'Date': datetime.datetime(1962, 7, 1, 0, 0, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>), 'Open': 0.0, 'High': 0.31637683540998823, 'Low': 0.28291394466815123, 'Close': 0.3095322251319885, 'Volume': 5671908, 'Dividends': 0.0, 'Stock_Splits': 0.0}, {'Date': datetime.datetime(1962, 8, 1, 0, 0, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>), 'Open': 0.0, 'High': 0.3399532215107402, 'Low': 0.29280085771269737, 'Close': 0.32854539155960083, 'Volume': 5532216, 'Dividends': 0.0125, 'Stock_Splits': 0.0}, {'Date': datetime.datetime(1962, 9, 1, 0, 0, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>), 'Open': 0.0, 'High': 0.33458746835860786, 'Low': 0.2925730984889431, 'Close': 0.29639261960983276, 'Volume': 3716210, 'Dividends': 0.0, 'Stock_Splits': 0.0}  ... displaying 10 of 749 total bound parameter sets ...  {'Date': datetime.datetime(2024, 5, 1, 0, 0, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>), 'Open': 97.42337975247803, 'High': 105.30861813287194, 'Low': 94.35469584480703, 'Close': 99.44931030273438, 'Volume': 121987400, 'Dividends': 0.7, 'Stock_Splits': 0.0}, {'Date': datetime.datetime(2024, 6, 1, 0, 0, tzinfo=<DstTzInfo 'America/New_York' EDT-1 day, 20:00:00 DST>), 'Open': 100.37000274658203, 'High': 100.79000091552734, 'Low': 98.97000122070312, 'Close': 99.76000213623047, 'Volume': 0, 'Dividends': 0.0, 'Stock_Splits': 0.0}]]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %%
# db.show_tables(show_rows = True)
# Out:
# (1, 'MMM')
# (2, 'AOS')
# (3, 'ABT')
# (4, 'ABBV')
# (5, 'ACN')
# (6, 'ADBE')
# (7, 'AMD')
# (8, 'AES')
# (9, 'AFL')
# (10, 'A')
# (11, 'APD')
# (12, 'ABNB')
# (13, 'AKAM')
# (14, 'ALB')
# (15, 'ARE')
# (16, 'ALGN')
# (17, 'ALLE')
# (18, 'LNT')
# (19, 'ALL')
# (20, 'GOOGL')

# %%
def convert_timestamps(df):
    for col in df.columns:
        if pd.api.types.is_datetime64_any_dtype(df[col]):

            df[col] = df[col].dt.strftime('%Y-%m-%d %H:%M')  # Converting to string format

    return df

# for day in data_dictionary:
#     for company in data_dictionary[day]:
#         data_dictionary[day][company] = convert_timestamps(data_dictionary[day][company])

# %%
# App(data_dictionary, news, earnings, financials)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
pd.DataFrame(news['MMM'])
# Out:
#                                    uuid  \
# 0  d8da651d-d809-3070-a9df-30a0f2545f20
# 1  75062ef6-14ef-3714-917c-92e988925622
# 2  94ee34d5-59fb-3d4b-a6bc-fef547c373db
# 3  ef3765c5-c8e5-31f9-a9d9-3aa3a35458af
# 4  f6372aeb-89d8-3ee2-b416-d7b30d5090ef
# 5  f74760d5-cb90-466e-bb12-b990b908cbd3
# 6  dd3eb0ff-f3a5-3d1c-aed7-d4e7de500c7b
# 7  b5e8e9c0-0f51-3bdd-9a50-256e2b7ff741
#
#                                                title            publisher  \
# 0  1 Wall Street Analyst Thinks 3M Stock Is Going...          Motley Fool
# 1  How 3M Is Innovating To Address Climate Challe...           ACCESSWIRE
# 2  3M (MMM) Stock Slides as Market Rises: Facts t...                Zacks
# 3  3M Company (NYSE:MMM) Upgraded by Bank of America       Insider Monkey
# 4  3M Named Official Respiratory Protection Spons...           ACCESSWIRE
# 5  Most CEOs are defeating attempts to vote down ...        Yahoo Finance
# 6        Industrial moves for the AI boom: Top picks  Yahoo Finance Video
# 7  Blue-Chip Steals: 3 Top-Tier Stocks Trading at...        InvestorPlace
#
#                                                 link  providerPublishTime  \
# 0  https://finance.yahoo.com/m/d8da651d-d809-3070...           1718124054
# 1  https://finance.yahoo.com/news/3m-innovating-a...           1718108100
# 2  https://finance.yahoo.com/news/3m-mmm-stock-sl...           1718055917
# 3  https://finance.yahoo.com/news/3m-company-nyse...           1718054453
# 4  https://finance.yahoo.com/news/3m-named-offici...           1718021700
# 5  https://finance.yahoo.com/news/most-ceos-are-d...           1718010250
# 6  https://finance.yahoo.com/video/industrial-mov...           1717792419
# 7  https://finance.yahoo.com/news/blue-chip-steal...           1717606800
#
#     type                                          thumbnail  \
# 0  STORY  {'resolutions': [{'url': 'https://s.yimg.com/u...
# 1  STORY  {'resolutions': [{'url': 'https://s.yimg.com/u...
# 2  STORY  {'resolutions': [{'url': 'https://s.yimg.com/u...
# 3  STORY  {'resolutions': [{'url': 'https://s.yimg.com/u...
# 4  STORY  {'resolutions': [{'url': 'https://s.yimg.com/u...
# 5  STORY  {'resolutions': [{'url': 'https://s.yimg.com/u...
# 6  VIDEO  {'resolutions': [{'url': 'https://s.yimg.com/u...
# 7  STORY  {'resolutions': [{'url': 'https://s.yimg.com/u...
#
#                                      relatedTickers
# 0                                             [MMM]
# 1                                             [MMM]
# 2                                             [MMM]
# 3                                             [MMM]
# 4                                             [MMM]
# 5  [^IXIC, ^GSPC, AZN, AZNCF, BLK, ^DJI, TSLA, MMM]
# 6                [NVT, XYL, HTHIF, HTHIY, ETN, MMM]
# 7                                     [ADM, MMM, T]

# %%
class App:
    def __init__(self, data_dict, news, earnings, financials):
        self.app = dash.Dash(__name__)
        self.data_dict = data_dict
        self.news_dict = news
        self.earnings_dict  = earnings
        self.financial_dict = financials
        self.news_cols      = ['title', 'publisher']
        
        self.news     = pd.DataFrame(news[list(earnings.keys())[0]])
        self.data     = data_dict[list(data_dict.keys())[0]]
        self.earnings = earnings[list(earnings.keys())[0]]
        self.financials = financials[list(financials.keys())[0]]
        self.default_col = list(self.data.keys())[0]
        self.periods = list(self.data_dict.keys())

        self.stock_columns = self.data[self.default_col].columns
        self.display_data  = self.data[self.default_col]
        self.companies     = self.get_companies(self.data)
        
        self.company   = self.companies[0]
        self.news = self.convert_type(self.news, ['thumbnail', 'link', 'relatedTickers'])[self.news_cols]
        self.app_layout()
        self.run_server()

    def update_periods(self, data_dict):
        ''' Update the default stock data periods '''
        time_periods = list(self.data_dict.keys())
        if time_periods != self.periods:
            periods = time_periods
        return periods

    def update_period(self, period):
        ''' Update the data to have a different time period '''
        return self.data_dict[period]

    def update_company(self, company):
        self.company = company
        return self.data[company]

    def get_companies(self, data):
        return list(data.keys())
    
    def run_server(self):
        self.app.run_server(debug=True)  

    def convert_type(self, x, col):
        if isinstance(x, list):
            for c in col:
                x[c] = x[c].astype(str)
        else:
            x[col] = x[col].astype(str)
        return x

    def update_news_data(self, company):
        
        self.news  = pd.DataFrame(self.news_dict[company])
        self.news  = self.convert_type(self.news, ['thumbnail', 'link', 'relatedTickers'])[self.news_cols]
        self.news  = self.news.to_dict('records')

        return self.news

    def app_layout(self):
        self.app.layout = html.Div([
            html.Div([
                html.H1('Stock Monitoring Dashboard')
            ], style={'textAlign': 'center'}),

            html.Div([
                html.Div([
                    dcc.Tabs(
                        id='tabs',
                        value='page-1',
                        vertical=True,
                        children=[
                            dcc.Tab(label='Stock History', value='page-1', children = self.render_page_1()),
                            dcc.Tab(label='Model Forecasts', value='page-2', children = self.render_page_2()),
                            dcc.Tab(label='Relevant News', value='page-3', children = self.render_page_3())
                        ],
                        style={
                            'height': '100vh',
                            'borderRight': '1px solid #d6d6d6',
                            'padding': '10px'
                        }
                    )
                ], style={'width': '20%', 'display': 'inline-block', 'verticalAlign': 'top'}),

                html.Div(id='page-content', style={'width': '75%', 'display': 'inline-block', 'padding': '10px'})
            ])
        ])

        # Initialize the layout with the default tab's content
        self.app.layout.children[-1].children[-1].children = self.render_page_1()

        @self.app.callback(Output('page-content', 'children'),
                           [Input('tabs', 'value')])
        
        # Insert some code to make sure page 1 doesn't return to original state
        # Make sure all states stay in the dashboard and transfer between pages. 
        def render_content(tab):
            if tab == 'page-1':
                return self.render_page_1()
            elif tab == 'page-2':
                return self.render_page_2()
            elif tab == 'page-3':
                return self.render_page_3()
            
        # Callback to update the content of the news table on page 3
        @self.app.callback(
            Output('news-table', 'data'),
            [Input('company-dropdown', 'value')],
            [State('tabs', 'value')]  # Include the state of the tabs to check if page 3 is active
        )

        def update_news_table(selected_company, current_tab):
            if current_tab != 'page-3' or not hasattr(self, 'news_initialized'):
                raise PreventUpdate  # Prevents the callback from executing

            return self.update_news_data(selected_company)

        @self.app.callback(
            # Output('news-table', 'data'), 
            Output('interactive-graph', 'figure'),
            [Input('company-dropdown', 'value'),
             Input('data-dropdown', 'value'),
             Input('period', 'value')]
        )
        def update_graph(selected_company, selected_data, period):
            self.data = self.update_period(period)
            display_data = self.update_company(selected_company)
            self.company
            fig = px.line(display_data, x='Date', y=selected_data, title=f'{selected_company} - {selected_data}', template='plotly_dark')
            return fig

    def render_page_1(self):
        return html.Div([
            html.Label('Select Company'),
            dcc.Dropdown(
                id='company-dropdown',
                options=[{'label': company, 'value': company} for company in self.companies],
                value=self.company
            ),
            html.Br(),
            html.Label('Stock Period'),
            dcc.Dropdown(
                id='period',
                options=[{'label': period, 'value': period} for period in self.periods],
                value=self.periods[0]
            ),
            html.Br(),
            html.Label('Select Data'),
            dcc.Dropdown(
                id='data-dropdown',
                options=[
                    {'label': category, 'value': category} for category in self.stock_columns[1:5]
                ],
                value='Close'
            ),
            dcc.Graph(id='interactive-graph')
        ])

    def render_page_2(self):
        return html.Div([
            html.H3('Earnings'),
            dash_table.DataTable(
                id='earnings-table',
                columns=[{'name': i, 'id': i} for i in self.earnings.columns],
                data=self.earnings.to_dict('records'),
                style_table={'overflowX': 'auto'},
                style_cell={'textAlign': 'left'},
                style_header={
                    'backgroundColor': 'rgb(230, 230, 230)',
                    'fontWeight': 'bold'
                },
                style_as_list_view=True,
                style_data={
                    'whiteSpace': 'normal',
                    'height': 'auto',
                    'lineHeight': '15px'
                }
            )
        ])

    def render_page_3(self):

        if not hasattr(self, 'news_initialized'):
            # Initialize or load data for news table
            self.news = self.update_news_data(self.company)
            self.news_initialized = True

        return html.Div([
            html.H3('News'),
            dash_table.DataTable(
                id='news-table',
                columns=[{'name': i, 'id': i} for i in self.news.columns],
                data=self.news.to_dict('records'),
                style_table={'overflowX': 'auto'},
                style_cell={'textAlign': 'left'},
                style_header={
                    'backgroundColor': 'rgb(230, 230, 230)',
                    'fontWeight': 'bold'
                },
                style_as_list_view=True,
                style_data={
                    'whiteSpace': 'normal',
                    'height': 'auto',
                    'lineHeight': '15px'
                }
            )
        ])

# %%
if __name__ == '__main__':
    App(data_dictionary, news, earnings, financials)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [97], in <cell line: 1>()
#       1 if __name__ == '__main__':
# ----> 2     App(data_dictionary, news, earnings, financials)
#
# Input In [96], in App.__init__(self, data_dict, news, earnings, financials)
#      21 self.company   = self.companies[0]
#      22 self.news = self.convert_type(self.news, ['thumbnail', 'link', 'relatedTickers'])[self.news_cols]
# ---> 23 self.app_layout()
#      24 self.run_server()
#
# Input In [96], in App.app_layout(self)
#      63 def app_layout(self):
#      64     self.app.layout = html.Div([
#      65         html.Div([
#      66             html.H1('Stock Monitoring Dashboard')
#      67         ], style={'textAlign': 'center'}),
#      68
#      69         html.Div([
#      70             html.Div([
#      71                 dcc.Tabs(
#      72                     id='tabs',
#      73                     value='page-1',
#      74                     vertical=True,
#      75                     children=[
#      76                         dcc.Tab(label='Stock History', value='page-1', children = self.render_page_1()),
#      77                         dcc.Tab(label='Model Forecasts', value='page-2', children = self.render_page_2()),
# ---> 78                         dcc.Tab(label='Relevant News', value='page-3', children = self.render_page_3())
#      79                     ],
#      80                     style={
#      81                         'height': '100vh',
#      82                         'borderRight': '1px solid #d6d6d6',
#      83                         'padding': '10px'
#      84                     }
#      85                 )
#      86             ], style={'width': '20%', 'display': 'inline-block', 'verticalAlign': 'top'}),
#      87
#      88             html.Div(id='page-content', style={'width': '75%', 'display': 'inline-block', 'padding': '10px'})
#      89         ])
#      90     ])
#      92     # Initialize the layout with the default tab's content
#      93     self.app.layout.children[-1].children[-1].children = self.render_page_1()
#
# Input In [96], in App.render_page_3(self)
#     188     self.news = self.update_news_data(self.company)
#     189     self.news_initialized = True
#     191 return html.Div([
#     192     html.H3('News'),
#     193     dash_table.DataTable(
#     194         id='news-table',
# --> 195         columns=[{'name': i, 'id': i} for i in self.news.columns],
#     196         data=self.news.to_dict('records'),
#     197         style_table={'overflowX': 'auto'},
#     198         style_cell={'textAlign': 'left'},
#     199         style_header={
#     200             'backgroundColor': 'rgb(230, 230, 230)',
#     201             'fontWeight': 'bold'
#     202         },
#     203         style_as_list_view=True,
#     204         style_data={
#     205             'whiteSpace': 'normal',
#     206             'height': 'auto',
#     207             'lineHeight': '15px'
#     208         }
#     209     )
#     210 ])
#
# AttributeError: 'list' object has no attribute 'columns'
